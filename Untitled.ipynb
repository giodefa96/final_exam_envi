# %%
import numpy as np

# %%
data_mo = np.load('/home/giodefa/Desktop/Unimib/Data Science/Second Year/Physics and environmental data lab/Environmental/Materiale Corso/Final_ex/final_exam_envi/bozza/array_comp_16200.npy')
data_mo.shape
# Out:
# (16200, 60)

# %%
pip install sktime[all_extras]
# Out:
# Requirement already satisfied: sktime[all_extras] in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: statsmodels>=0.12.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (0.13.2)
# Requirement already satisfied: numpy<1.22,>=1.21.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (1.21.6)
# Requirement already satisfied: scipy<1.8.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (1.6.2)
# Requirement already satisfied: numba>=0.53 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (0.55.1)
# Requirement already satisfied: scikit-learn>=0.24.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (1.0.1)
# Requirement already satisfied: pandas<1.5.0,>=1.1.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (1.2.4)
# Requirement already satisfied: deprecated>=1.2.13 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (1.2.13)
# Collecting statsforecast>=0.5.2
#   Downloading statsforecast-0.5.3-py3-none-any.whl (31 kB)
# Collecting dtw-python
#   Downloading dtw_python-1.1.12-cp37-cp37m-manylinux2010_x86_64.whl (580 kB)
#      |████████████████████████████████| 580 kB 5.8 MB/s eta 0:00:01
# Requirement already satisfied: seaborn>=0.11.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (0.11.2)
# Requirement already satisfied: tensorflow in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (2.2.0)
# Collecting tensorflow-probability
#   Downloading tensorflow_probability-0.16.0-py2.py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 6.1 MB/s eta 0:00:01
# Collecting esig==0.9.7
#   Downloading esig-0.9.7-cp37-cp37m-manylinux2010_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 32.3 MB/s eta 0:00:01
# Collecting tslearn>=0.5.2
#   Downloading tslearn-0.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (793 kB)
#      |████████████████████████████████| 793 kB 34.9 MB/s eta 0:00:01
# Collecting prophet>=1.0
#   Downloading prophet-1.0.1.tar.gz (65 kB)
#      |████████████████████████████████| 65 kB 3.6 MB/s  eta 0:00:01
# Collecting pmdarima!=1.8.1,>=1.8.0
#   Downloading pmdarima-1.8.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 41.2 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.3.2 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from sktime[all_extras]) (3.4.3)
# Collecting pyod>=0.8.0
#   Downloading pyod-0.9.9.tar.gz (116 kB)
#      |████████████████████████████████| 116 kB 9.7 MB/s eta 0:00:01
# Collecting hcrystalball>=0.1.9
#   Downloading hcrystalball-0.1.12-py2.py3-none-any.whl (788 kB)
#      |████████████████████████████████| 788 kB 10.2 MB/s eta 0:00:01
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 3.2 MB/s  eta 0:00:01
# Collecting scikit-posthocs>=0.6.5
#   Downloading scikit-posthocs-0.6.7.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.3 MB/s  eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting stumpy>=1.5.1
#   Downloading stumpy-1.11.1-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 11.5 MB/s eta 0:00:01
# Collecting pystan==2.19.1.1
#   Downloading pystan-2.19.1.1-cp37-cp37m-manylinux1_x86_64.whl (67.3 MB)
#      |████████████████████████████████| 67.3 MB 9.9 MB/s eta 0:00:011     |████████████████████▉           | 43.9 MB 7.2 MB/s eta 0:00:04
# Collecting tsfresh>=0.17.0
#   Downloading tsfresh-0.19.0-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 4.8 MB/s  eta 0:00:01
# Collecting Cython!=0.25.1,>=0.22
#   Downloading Cython-0.29.28-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: wrapt<2,>=1.10 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from deprecated>=1.2.13->sktime[all_extras]) (1.12.1)
# Collecting workalendar>=10.1
#   Downloading workalendar-16.3.0-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 9.8 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (8.4.0)
# Requirement already satisfied: setuptools in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from numba>=0.53->sktime[all_extras]) (58.0.4)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from numba>=0.53->sktime[all_extras]) (0.38.0)
# Requirement already satisfied: pytz>=2017.3 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from pandas<1.5.0,>=1.1.0->sktime[all_extras]) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from pmdarima!=1.8.1,>=1.8.0->sktime[all_extras]) (1.1.0)
# Requirement already satisfied: urllib3 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from pmdarima!=1.8.1,>=1.8.0->sktime[all_extras]) (1.25.11)
# Collecting cmdstanpy==0.9.68
#   Downloading cmdstanpy-0.9.68-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.8 MB/s  eta 0:00:01
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 2.9 MB/s  eta 0:00:01
# Collecting holidays>=0.10.2
#   Downloading holidays-0.13-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 10.3 MB/s eta 0:00:01
# Collecting setuptools-git>=1.2
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from prophet>=1.0->sktime[all_extras]) (4.62.3)
# Collecting ujson
#   Downloading ujson-5.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.4 MB/s  eta 0:00:01
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.11.tar.gz (5.4 MB)
#      |████████████████████████████████| 5.4 MB 8.5 MB/s eta 0:00:01
# Collecting hijri-converter
#   Downloading hijri_converter-2.2.3-py3-none-any.whl (14 kB)
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.2.1-py3-none-any.whl (8.0 kB)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 40.4 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from pyod>=0.8.0->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from scikit-learn>=0.24.0->sktime[all_extras]) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from statsmodels>=0.12.1->sktime[all_extras]) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from statsmodels>=0.12.1->sktime[all_extras]) (0.5.2)
# Collecting matrixprofile<2.0.0,>=1.1.10
#   Downloading matrixprofile-1.1.10-cp37-cp37m-manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 35.1 MB/s eta 0:00:01
# Requirement already satisfied: cloudpickle in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tsfresh>=0.17.0->sktime[all_extras]) (2.0.0)
# Collecting dask[dataframe]>=2.9.0
#   Downloading dask-2022.2.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.9.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tsfresh>=0.17.0->sktime[all_extras]) (2.26.0)
# Collecting distributed>=2.11.0
#   Downloading distributed-2022.2.0-py3-none-any.whl (837 kB)
#      |████████████████████████████████| 837 kB 11.2 MB/s eta 0:00:01
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 9.8 MB/s eta 0:00:01
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from dask[dataframe]>=2.9.0->tsfresh>=0.17.0->sktime[all_extras]) (6.0)
# Collecting toolz>=0.8.2
#   Downloading toolz-0.11.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.7 MB/s  eta 0:00:01
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: tornado>=5 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (6.1)
# Requirement already satisfied: click>=6.6 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (7.1.2)
# Requirement already satisfied: jinja2 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (3.0.2)
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      |████████████████████████████████| 299 kB 10.5 MB/s eta 0:00:01
# Collecting psutil>=5.0
#   Downloading psutil-5.9.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 10.9 MB/s eta 0:00:01
# Collecting zict>=0.1.3
#   Downloading zict-2.1.0-py3-none-any.whl (11 kB)
# Collecting protobuf==3.11.2
#   Downloading protobuf-3.11.2-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 33.8 MB/s eta 0:00:01
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2021.10.8)
# Collecting pyluach
#   Downloading pyluach-1.4.1-py3-none-any.whl (18 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp37-cp37m-manylinux1_x86_64.whl (70 kB)
#      |████████████████████████████████| 70 kB 7.6 MB/s  eta 0:00:01
# Collecting lunardate
#   Downloading lunardate-0.2.0-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: importlib-metadata in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from workalendar>=10.1->hcrystalball>=0.1.9->sktime[all_extras]) (4.8.2)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: zipp>=0.5 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from importlib-metadata->workalendar>=10.1->hcrystalball>=0.1.9->sktime[all_extras]) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from importlib-metadata->workalendar>=10.1->hcrystalball>=0.1.9->sktime[all_extras]) (3.10.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from jinja2->distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (2.0.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (2.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (0.37.0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (2.2.1)
# Requirement already satisfied: grpcio>=1.8.6 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (1.31.0)
# Requirement already satisfied: astunparse==1.6.3 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (1.6.3)
# Requirement already satisfied: absl-py>=0.7.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (0.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow->sktime[all_extras]) (3.1.0)
# Collecting tensorflow
#   Downloading tensorflow-2.8.0-cp37-cp37m-manylinux2010_x86_64.whl (497.5 MB)
#      |████████████████████████████████| 497.5 MB 33 kB/s s eta 0:00:01  |▎                               | 4.3 MB 7.2 MB/s eta 0:01:09     |██████████████████████▍         | 348.9 MB 9.3 MB/s eta 0:00:17     |█████████████████████████████▋  | 460.9 MB 8.7 MB/s eta 0:00:05
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorboard<2.9,>=2.8
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Collecting keras<2.9,>=2.8.0rc0
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Collecting flatbuffers>=1.12
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 9.2 MB/s eta 0:00:01
# Collecting libclang>=9.0.1
#   Using cached libclang-13.0.0-py2.py3-none-manylinux1_x86_64.whl (14.5 MB)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (3.3.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (1.6.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (1.22.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->sktime[all_extras]) (3.1.0)
# Requirement already satisfied: decorator in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from tensorflow-probability->sktime[all_extras]) (5.1.0)
# Collecting dm-tree
#   Downloading dm_tree-0.1.7-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (143 kB)
#      |████████████████████████████████| 143 kB 10.0 MB/s eta 0:00:01
# Building wheels for collected packages: prophet, pymeeus, pyod, scikit-posthocs
#   Building wheel for prophet (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/giodefa/miniconda3/envs/tensorflow/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/setup.py'"'"'; __file__='"'"'/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-b83_ho76
#        cwd: /tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/
#   Complete output (44 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/prophet
#   creating build/lib/prophet/stan_model
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/setup.py", line 150, in <module>
#       long_description_content_type='text/markdown',
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages/wheel/bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/setup.py", line 48, in run
#       build_models(target_dir)
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/setup.py", line 36, in build_models
#       from prophet.models import StanBackendEnum
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/prophet/__init__.py", line 8, in <module>
#       from prophet.forecaster import Prophet
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/prophet/forecaster.py", line 17, in <module>
#       from prophet.make_holidays import get_holiday_names, make_holidays_df
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/prophet/make_holidays.py", line 14, in <module>
#       import prophet.hdays as hdays_part2
#     File "/tmp/pip-install-_ze3lv6c/prophet_3576aa12ded5418d864e35012b9a3f0d/prophet/hdays.py", line 13, in <module>
#       from convertdate.islamic import from_gregorian, to_gregorian
#   ModuleNotFoundError: No module named 'convertdate'
#   ----------------------------------------
#   ERROR: Failed building wheel for prophet
#   Running setup.py clean for prophet
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.11-py3-none-any.whl size=730984 sha256=00b4a187d471f2986fbb552bd0933beb6fdd5ba5fdf105aa5f51c35eb7bfcac6
#   Stored in directory: /home/giodefa/.cache/pip/wheels/33/6b/a6/1d9dae2323750f635654952afc74aa8f2d982cded163f43895
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-0.9.9-py3-none-any.whl size=139322 sha256=6b9a6134583fd33659fc8b5c65a0e7a2a86db969d772ee6eb0aada4144c24e5d
#   Stored in directory: /home/giodefa/.cache/pip/wheels/68/32/f0/0dc3050775e77b6661a116b70817b02b4305fa253269d6d998
#   Building wheel for scikit-posthocs (PEP 517) ... done
#   Created wheel for scikit-posthocs: filename=scikit_posthocs-0.6.7-py3-none-any.whl size=37903 sha256=4b2ef09bb36dfdecac3775aecdff0bab3a7912744008ee43536c6e4fb5242cce
#   Stored in directory: /home/giodefa/.cache/pip/wheels/b8/21/e6/f39794d4a6ee3d3cc5146ca80b5cd949452ad4a8fde9f6b9fc
# Successfully built pymeeus pyod scikit-posthocs
# Failed to build prophet
# Installing collected packages: toolz, locket, pymeeus, partd, heapdict, fsspec, zict, ujson, tensorboard-data-server, tblib, sortedcontainers, pyluach, psutil, protobuf, msgpack, lunardate, korean-lunar-calendar, hijri-converter, ephem, dask, Cython, convertdate, backports.zoneinfo, workalendar, tf-estimator-nightly, tensorflow-io-gcs-filesystem, tensorboard, stumpy, setuptools-git, pystan, pmdarima, matrixprofile, LunarCalendar, libclang, keras-preprocessing, keras, holidays, flatbuffers, dm-tree, distributed, cmdstanpy, tslearn, tsfresh, tensorflow-probability, tensorflow, tbats, statsforecast, scikit-posthocs, pyod, prophet, hcrystalball, esig, dtw-python
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.13.0
#     Uninstalling protobuf-3.13.0:
#       Successfully uninstalled protobuf-3.13.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Attempting uninstall: keras-preprocessing
#     Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
#     Running setup.py install for prophet ... done
#   DEPRECATION: prophet was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Successfully installed Cython-0.29.28 LunarCalendar-0.0.9 backports.zoneinfo-0.2.1 cmdstanpy-0.9.68 convertdate-2.4.0 dask-2022.2.0 distributed-2022.2.0 dm-tree-0.1.7 dtw-python-1.1.12 ephem-4.1.3 esig-0.9.7 flatbuffers-2.0 fsspec-2022.3.0 hcrystalball-0.1.12 heapdict-1.0.1 hijri-converter-2.2.3 holidays-0.13 keras-2.8.0 keras-preprocessing-1.1.2 korean-lunar-calendar-0.2.1 libclang-13.0.0 locket-0.2.1 lunardate-0.2.0 matrixprofile-1.1.10 msgpack-1.0.3 partd-1.2.0 pmdarima-1.8.5 prophet-1.0.1 protobuf-3.11.2 psutil-5.9.0 pyluach-1.4.1 pymeeus-0.5.11 pyod-0.9.9 pystan-2.19.1.1 scikit-posthocs-0.6.7 setuptools-git-1.2 sortedcontainers-2.4.0 statsforecast-0.5.3 stumpy-1.11.1 tbats-1.1.0 tblib-1.7.0 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.24.0 tensorflow-probability-0.16.0 tf-estimator-nightly-2.8.0.dev2021122109 toolz-0.11.2 tsfresh-0.19.0 tslearn-0.5.2 ujson-5.2.0 workalendar-16.3.0 zict-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dtaidistance
# Out:
# Collecting dtaidistance
#   Downloading dtaidistance-2.3.6.tar.gz (797 kB)
#      |████████████████████████████████| 797 kB 2.5 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /home/giodefa/miniconda3/envs/tensorflow/lib/python3.7/site-packages (from dtaidistance) (1.21.6)
# Building wheels for collected packages: dtaidistance
#   Building wheel for dtaidistance (PEP 517) ... done
#   Created wheel for dtaidistance: filename=dtaidistance-2.3.6-cp37-cp37m-linux_x86_64.whl size=2064880 sha256=0b5f41f982d2ee31bf311cabb2d0a67cb3734a300827d96c7c52b7d94d2b21ea
#   Stored in directory: /home/giodefa/.cache/pip/wheels/a4/04/e5/ff7fd821276e7ec68893652d36b6a13f230ecdcafdc3283b3f
# Successfully built dtaidistance
# Installing collected packages: dtaidistance
# Successfully installed dtaidistance-2.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis
